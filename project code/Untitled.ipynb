# %%
import numpy as np
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
import glob
image_list = []
list1=[]
for x in data['VideoName']:
    file1=x
    image_list=[]
    for filename in glob.glob(r"C:\Users\garla\Desktop\majorproject\project\videos"+"\"+file1):
        print(filename) #assuming gif
        im=Image.open(filename)
        np_img = np.array(im)
        #print(type(np_img))
        #print(np_img.shape)
        image_list.append(np_img)
        print(image_list)
    list1.append(image_list)
    
print(list1)
# Out:
#   File "<ipython-input-38-9190651edf2d>", line 8
#     for filename in glob.glob(r"C:\Users\garla\Desktop\majorproject\project\videos"+"\"+file1):
#                                                                                                ^
# SyntaxError: EOL while scanning string literal

# %%
data=pd.read_csv('data.csv')
